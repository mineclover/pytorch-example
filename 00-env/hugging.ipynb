# %%
# %conda install ipykernel
# %conda install numpy pandas matplotlib
# %conda install -c conda-forge ipywidgets  tqdm


# %conda install -c conda-forge ipywidgets  tqdm
# %conda install -c conda-forge pyarrow
# %pip install datasets sacremoses

# cuda가 글로벌에 설치되있으면 cuda 설치는 생략됨
# window
# %pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# mac
# %pip install torch torchvision torchaudio
# %pip install seaborn
# %pip install hf_xet
# %pip install transformers datasets evaluate accelerate scikit-learn sacrebleu sentencepiece
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: p:\Project\pytorch-example\.conda
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     freetype-2.13.3            |       h0620614_0         554 KB
#     qtdeclarative-6.7.3        |       h5da7b33_0        21.4 MB
#     qtsvg-6.7.3                |       hf2fb9eb_0         314 KB
#     qttools-6.7.3              |       h0de5f00_0         9.4 MB
#     qtwebchannel-6.7.3         |       h5da7b33_0         162 KB
#     qtwebsockets-6.7.3         |       h5da7b33_0         147 KB
#     ------------------------------------------------------------
#                                            Total:        31.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   bottleneck         pkgs/main/win-64::bottleneck-1.4.2-py311h57dcf0c_0
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311h5da7b33_9
#   contourpy          pkgs/main/win-64::contourpy-1.3.1-py311h214f63a_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/win-64::fonttools-4.55.3-py311h827c3e9_0
#   freetype           pkgs/main/win-64::freetype-2.13.3-h0620614_0
#   icu                conda-forge/win-64::icu-73.2-h63175ca_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2023.1.0-h59b6b97_46320
#   jpeg               pkgs/main/win-64::jpeg-9e-h827c3e9_3
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.8-py311h5da7b33_0
#   lcms2              pkgs/main/win-64::lcms2-2.16-hb4a4139_0
#   lerc               pkgs/main/win-64::lerc-4.0.0-h5da7b33_0
#   libdeflate         pkgs/main/win-64::libdeflate-1.22-h5bf469e_0
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0
#   libpq              conda-forge/win-64::libpq-17.0-hfc46ca6_0
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-h44ae7cf_1
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.3.2-h3d04722_1
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   matplotlib         pkgs/main/win-64::matplotlib-3.10.0-py311haa95532_0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.10.0-py311he19b0ae_0
#   mkl                pkgs/main/win-64::mkl-2023.1.0-h6b88ed4_46358
#   mkl-service        pkgs/main/win-64::mkl-service-2.4.0-py311h827c3e9_2
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.11-py311h827c3e9_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.2.8-py311hea22821_0
#   numexpr            pkgs/main/win-64::numexpr-2.10.1-py311h4cd664f_0
#   numpy              pkgs/main/win-64::numpy-2.2.4-py311hb0d8612_0
#   numpy-base         pkgs/main/win-64::numpy-base-2.2.4-py311h557a8af_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.5.2-hae555c5_0
#   pandas             pkgs/main/win-64::pandas-2.2.3-py311h5da7b33_0
#   pillow             pkgs/main/win-64::pillow-11.1.0-py311h096bfcc_0
#   pyparsing          pkgs/main/win-64::pyparsing-3.2.0-py311haa95532_0
#   pyqt               pkgs/main/win-64::pyqt-6.7.1-py311h5da7b33_0
#   pyqt6-sip          pkgs/main/win-64::pyqt6-sip-13.9.1-py311h827c3e9_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   pytz               pkgs/main/win-64::pytz-2024.1-py311haa95532_0
#   qtbase             pkgs/main/win-64::qtbase-6.7.3-h0804d20_0
#   qtdeclarative      pkgs/main/win-64::qtdeclarative-6.7.3-h5da7b33_0
#   qtsvg              pkgs/main/win-64::qtsvg-6.7.3-hf2fb9eb_0
#   qttools            pkgs/main/win-64::qttools-6.7.3-h0de5f00_0
#   qtwebchannel       pkgs/main/win-64::qtwebchannel-6.7.3-h5da7b33_0
#   qtwebsockets       pkgs/main/win-64::qtwebsockets-6.7.3-h5da7b33_0
#   sip                pkgs/main/win-64::sip-6.10.0-py311h5da7b33_0
#   tbb                pkgs/main/win-64::tbb-2021.8.0-h59b6b97_0
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py311h827c3e9_1
#   zstd               pkgs/main/win-64::zstd-1.5.6-h8880b57_0
#
# The following packages will be DOWNGRADED:
#
#   setuptools                         75.8.0-py311haa95532_0 --> 72.1.0-py311haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# qtdeclarative-6.7.3  | 21.4 MB   |            |   0%
#
# qttools-6.7.3        | 9.4 MB    |            |   0%
#
#
# freetype-2.13.3      | 554 KB    |            |   0%
#
#
#
# qtsvg-6.7.3          | 314 KB    |            |   0%
#
#
#
#
# qtwebchannel-6.7.3   | 162 KB    |            |   0%
#
#
#
#
#
# qtwebsockets-6.7.3   | 147 KB    |            |   0%
#
#
# freetype-2.13.3      | 554 KB    | 2          |   3%
#
# qttools-6.7.3        | 9.4 MB    | 2          |   3%
#
#
#
#
# qtwebchannel-6.7.3   | 162 KB    | ###9       |  40%
# qtdeclarative-6.7.3  | 21.4 MB   |            |   0%
#
#
#
# qtsvg-6.7.3          | 314 KB    | 5          |   5%
#
#
#
#
# qtwebchannel-6.7.3   | 162 KB    | ########## | 100%
#
#
#
#
#
# qtwebsockets-6.7.3   | 147 KB    | #          |  11%
#
# qttools-6.7.3        | 9.4 MB    | 5          |   5%
#
#
# freetype-2.13.3      | 554 KB    | ####9      |  49%
# qtdeclarative-6.7.3  | 21.4 MB   | 1          |   2%
#
#
#
#
#
# qtwebsockets-6.7.3   | 147 KB    | ########## | 100%
#
#
#
# qtsvg-6.7.3          | 314 KB    | #######6   |  76%
#
#
#
# qtsvg-6.7.3          | 314 KB    | ########## | 100%
#
#
#
#
# qtwebchannel-6.7.3   | 162 KB    | ########## | 100%
#
#
#
#
# qtwebchannel-6.7.3   | 162 KB    | ########## | 100%
#
#
# freetype-2.13.3      | 554 KB    | ########## | 100%
#
# qttools-6.7.3        | 9.4 MB    | 8          |   9%
# qtdeclarative-6.7.3  | 21.4 MB   | 4          |   4%
#
#
#
#
#
# qtwebsockets-6.7.3   | 147 KB    | ########## | 100%
#
#
#
#
#
# qtwebsockets-6.7.3   | 147 KB    | ########## | 100%
# qtdeclarative-6.7.3  | 21.4 MB   | 8          |   8%
#
#
#
# qtsvg-6.7.3          | 314 KB    | ########## | 100%
#
#
# freetype-2.13.3      | 554 KB    | ########## | 100%
#
#
# freetype-2.13.3      | 554 KB    | ########## | 100%
#
# qttools-6.7.3        | 9.4 MB    | #1         |  12%
# qtdeclarative-6.7.3  | 21.4 MB   | #2         |  12%
#
# qttools-6.7.3        | 9.4 MB    | #4         |  15%
# qtdeclarative-6.7.3  | 21.4 MB   | #6         |  16%
#
# qttools-6.7.3        | 9.4 MB    | #8         |  18%
# qtdeclarative-6.7.3  | 21.4 MB   | ##         |  20%
#
# qttools-6.7.3        | 9.4 MB    | ##1        |  21%
# qtdeclarative-6.7.3  | 21.4 MB   | ##4        |  24%
#
# qttools-6.7.3        | 9.4 MB    | ##5        |  25%
# qtdeclarative-6.7.3  | 21.4 MB   | ##8        |  28%
#
# qttools-6.7.3        | 9.4 MB    | ##9        |  29%
# qtdeclarative-6.7.3  | 21.4 MB   | ###1       |  32%
#
# qttools-6.7.3        | 9.4 MB    | ###4       |  35%
# qtdeclarative-6.7.3  | 21.4 MB   | ###5       |  35%
#
# qttools-6.7.3        | 9.4 MB    | ###9       |  39%
# qtdeclarative-6.7.3  | 21.4 MB   | ###8       |  39%
#
# qttools-6.7.3        | 9.4 MB    | ####3      |  44%
# qtdeclarative-6.7.3  | 21.4 MB   | ####2      |  42%
#
# qttools-6.7.3        | 9.4 MB    | ####9      |  49%
# qtdeclarative-6.7.3  | 21.4 MB   | ####5      |  45%
#
# qttools-6.7.3        | 9.4 MB    | #####4     |  54%
#
# qttools-6.7.3        | 9.4 MB    | #####9     |  60%
# qtdeclarative-6.7.3  | 21.4 MB   | ####8      |  49%
#
# qttools-6.7.3        | 9.4 MB    | ######5    |  65%
# qtdeclarative-6.7.3  | 21.4 MB   | #####1     |  52%
#
# qttools-6.7.3        | 9.4 MB    | #######    |  71%
# qtdeclarative-6.7.3  | 21.4 MB   | #####4     |  55%
# qtdeclarative-6.7.3  | 21.4 MB   | #####7     |  58%
#
# qttools-6.7.3        | 9.4 MB    | #######5   |  76%
#
# qttools-6.7.3        | 9.4 MB    | ########1  |  81%
# qtdeclarative-6.7.3  | 21.4 MB   | ######     |  61%
#
# qttools-6.7.3        | 9.4 MB    | ########6  |  87%
# qtdeclarative-6.7.3  | 21.4 MB   | ######3    |  64%
#
# qttools-6.7.3        | 9.4 MB    | #########2 |  93%
# qtdeclarative-6.7.3  | 21.4 MB   | ######6    |  67%
#
# qttools-6.7.3        | 9.4 MB    | #########8 |  99%
# qtdeclarative-6.7.3  | 21.4 MB   | ######9    |  69%
#
# qttools-6.7.3        | 9.4 MB    | ########## | 100%
# qtdeclarative-6.7.3  | 21.4 MB   | #######4   |  74%
# qtdeclarative-6.7.3  | 21.4 MB   | #######9   |  79%
# qtdeclarative-6.7.3  | 21.4 MB   | ########3  |  84%
# qtdeclarative-6.7.3  | 21.4 MB   | ########7  |  87%
#
# qttools-6.7.3        | 9.4 MB    | ########## | 100%
# qtdeclarative-6.7.3  | 21.4 MB   | #########2 |  93%
# qtdeclarative-6.7.3  | 21.4 MB   | #########7 |  97%
# qtdeclarative-6.7.3  | 21.4 MB   | ########## | 100%
# qtdeclarative-6.7.3  | 21.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: p:\Project\pytorch-example\.conda
#
#   added / updated specs:
#     - ipywidgets
#     - tqdm
#
#
# The following NEW packages will be INSTALLED:
#
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.6-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.14-pyhd8ed1ab_0
#   tqdm               conda-forge/noarch::tqdm-4.67.1-pyhd8ed1ab_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.14-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: p:\Project\pytorch-example\.conda
#
#   added / updated specs:
#     - pyarrow
#
#
# The following NEW packages will be INSTALLED:
#
#   aws-c-auth         conda-forge/win-64::aws-c-auth-0.7.22-ha390a07_2
#   aws-c-cal          conda-forge/win-64::aws-c-cal-0.6.14-h750c3ff_1
#   aws-c-common       conda-forge/win-64::aws-c-common-0.9.19-h2466b09_0
#   aws-c-compression  conda-forge/win-64::aws-c-compression-0.2.18-h750c3ff_6
#   aws-c-event-stream conda-forge/win-64::aws-c-event-stream-0.4.2-he05106e_12
#   aws-c-http         conda-forge/win-64::aws-c-http-0.8.1-h55c4ea9_17
#   aws-c-io           conda-forge/win-64::aws-c-io-0.14.8-ha255af7_5
#   aws-c-mqtt         conda-forge/win-64::aws-c-mqtt-0.10.4-heb8cf2b_4
#   aws-c-s3           conda-forge/win-64::aws-c-s3-0.5.9-haf5e0f7_3
#   aws-c-sdkutils     conda-forge/win-64::aws-c-sdkutils-0.1.16-h750c3ff_2
#   aws-checksums      conda-forge/win-64::aws-checksums-0.1.18-h750c3ff_6
#   aws-crt-cpp        conda-forge/win-64::aws-crt-cpp-0.26.9-hb2f7e64_0
#   aws-sdk-cpp        conda-forge/win-64::aws-sdk-cpp-1.11.329-h752cf48_3
#   c-ares             conda-forge/win-64::c-ares-1.34.5-h2466b09_0
#   libabseil          conda-forge/win-64::libabseil-20240116.2-cxx17_he0c23c2_1
#   libarrow           conda-forge/win-64::libarrow-16.1.0-h35ad6a0_6_cpu
#   libarrow-acero     conda-forge/win-64::libarrow-acero-16.1.0-he0c23c2_6_cpu
#   libarrow-dataset   conda-forge/win-64::libarrow-dataset-16.1.0-he0c23c2_6_cpu
#   libarrow-substrait conda-forge/win-64::libarrow-substrait-16.1.0-h1f0e801_6_cpu
#   libbrotlicommon    conda-forge/win-64::libbrotlicommon-1.1.0-h2466b09_2
#   libbrotlidec       conda-forge/win-64::libbrotlidec-1.1.0-h2466b09_2
#   libbrotlienc       conda-forge/win-64::libbrotlienc-1.1.0-h2466b09_2
#   libcrc32c          conda-forge/win-64::libcrc32c-1.1.2-h0e60522_0
#   libcurl            conda-forge/win-64::libcurl-8.8.0-hd5e4a3a_1
#   libevent           conda-forge/win-64::libevent-2.1.12-h3671451_1
#   libgoogle-cloud    conda-forge/win-64::libgoogle-cloud-2.24.0-h5e7cea3_0
#   libgoogle-cloud-s~ conda-forge/win-64::libgoogle-cloud-storage-2.24.0-hce61461_0
#   libgrpc            conda-forge/win-64::libgrpc-1.62.2-h5273850_0
#   libparquet         conda-forge/win-64::libparquet-16.1.0-h178134c_6_cpu
#   libprotobuf        conda-forge/win-64::libprotobuf-4.25.3-h503648d_0
#   libre2-11          conda-forge/win-64::libre2-11-2023.09.01-hf8d8778_2
#   libssh2            conda-forge/win-64::libssh2-1.11.0-h7dfc565_0
#   libthrift          conda-forge/win-64::libthrift-0.19.0-ha2b3283_1
#   libutf8proc        conda-forge/win-64::libutf8proc-2.8.0-hb602f4b_1
#   libzlib            conda-forge/win-64::libzlib-1.2.13-h2466b09_6
#   orc                conda-forge/win-64::orc-2.0.1-h7e885a9_1
#   pyarrow            conda-forge/win-64::pyarrow-16.1.0-py311h06a5be4_2
#   pyarrow-core       conda-forge/win-64::pyarrow-core-16.1.0-py311h4f35fbc_2_cpu
#   re2                conda-forge/win-64::re2-2023.09.01-hd3b24a8_2
#   snappy             conda-forge/win-64::snappy-1.2.1-h500f7fa_1
#
# The following packages will be UPDATED:
#
#   zlib                    pkgs/main::zlib-1.2.13-h8cc25b3_1 --> conda-forge::zlib-1.2.13-h2466b09_6
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# Collecting datasets
#   Using cached datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting sacremoses
#   Using cached sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting filelock (from datasets)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.17 in p:\project\pytorch-example\.conda\lib\site-packages (from datasets) (2.2.4)
# Requirement already satisfied: pyarrow>=15.0.0 in p:\project\pytorch-example\.conda\lib\site-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in p:\project\pytorch-example\.conda\lib\site-packages (from datasets) (2.2.3)
# Collecting requests>=2.32.2 (from datasets)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.66.3 in p:\project\pytorch-example\.conda\lib\site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.11.16-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in p:\project\pytorch-example\.conda\lib\site-packages (from datasets) (24.2)
# Collecting pyyaml>=5.1 (from datasets)
#   Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting regex (from sacremoses)
#   Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting click (from sacremoses)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from sacremoses)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.5.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.4.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets)
#   Using cached propcache-0.3.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets)
#   Downloading yarl-1.19.0-cp311-cp311-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in p:\project\pytorch-example\.conda\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Collecting charset-normalizer<4,>=2 (from requests>=2.32.2->datasets)
#   Using cached charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.2->datasets)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->datasets)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: colorama in p:\project\pytorch-example\.conda\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in p:\project\pytorch-example\.conda\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in p:\project\pytorch-example\.conda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in p:\project\pytorch-example\.conda\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in p:\project\pytorch-example\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached datasets-3.5.0-py3-none-any.whl (491 kB)
# Using cached sacremoses-0.1.1-py3-none-any.whl (897 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading aiohttp-3.11.16-cp311-cp311-win_amd64.whl (442 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
# Using cached xxhash-3.5.0-cp311-cp311-win_amd64.whl (30 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
# Using cached frozenlist-1.5.0-cp311-cp311-win_amd64.whl (51 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading multidict-6.4.3-cp311-cp311-win_amd64.whl (38 kB)
# Using cached propcache-0.3.1-cp311-cp311-win_amd64.whl (45 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading yarl-1.19.0-cp311-cp311-win_amd64.whl (93 kB)
# Installing collected packages: xxhash, urllib3, regex, pyyaml, propcache, multidict, joblib, idna, fsspec, frozenlist, filelock, dill, click, charset-normalizer, certifi, attrs, aiohappyeyeballs, yarl, sacremoses, requests, multiprocess, aiosignal, huggingface-hub, aiohttp, datasets
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aiosignal-1.3.2 attrs-25.3.0 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 datasets-3.5.0 dill-0.3.8 filelock-3.18.0 frozenlist-1.5.0 fsspec-2024.12.0 huggingface-hub-0.30.2 idna-3.10 joblib-1.4.2 multidict-6.4.3 multiprocess-0.70.16 propcache-0.3.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 sacremoses-0.1.1 urllib3-2.4.0 xxhash-3.5.0 yarl-1.19.0
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%pip3` not found.

# %%
# Out:
# Collecting torch
#   Using cached torch-2.6.0-cp311-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting torchvision
#   Using cached torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.6.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torch) (4.13.2)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torchvision) (11.1.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Using cached torch-2.6.0-cp311-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached torchaudio-2.6.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision, torchaudio
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 sympy-1.13.1 torch-2.6.0 torchaudio-2.6.0 torchvision-0.21.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformers
#   Downloading transformers-4.51.2-py3-none-any.whl.metadata (38 kB)
# Collecting datasets
#   Using cached datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting accelerate
#   Downloading accelerate-1.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from transformers) (3.18.0)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from transformers) (24.2)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from transformers)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Using cached pyarrow-19.0.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from datasets) (2.2.3)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.11.16-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=2.0.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from accelerate) (2.6.0)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting tabulate>=0.8.9 (from sacrebleu)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lxml (from sacrebleu)
#   Downloading lxml-5.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Using cached frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.4.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets)
#   Using cached propcache-0.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets)
#   Downloading yarl-1.19.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (71 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Collecting charset-normalizer<4,>=2 (from requests->transformers)
#   Using cached charset_normalizer-3.4.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->transformers)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/hugging/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Downloading transformers-4.51.2-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 10.2 MB/s eta 0:00:00 0:00:01
# Using cached datasets-3.5.0-py3-none-any.whl (491 kB)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
# Downloading accelerate-1.6.0-py3-none-any.whl (354 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 8.0 MB/s eta 0:00:00a 0:00:01
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Using cached sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading aiohttp-3.11.16-cp311-cp311-macosx_11_0_arm64.whl (456 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached pyarrow-19.0.1-cp311-cp311-macosx_12_0_arm64.whl (30.7 MB)
# Using cached PyYAML-6.0.2-cp311-cp311-macosx_11_0_arm64.whl (172 kB)
# Using cached regex-2024.11.6-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading lxml-5.3.2-cp311-cp311-macosx_10_9_universal2.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Using cached xxhash-3.5.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp311-cp311-macosx_10_9_universal2.whl (194 kB)
# Using cached frozenlist-1.5.0-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading multidict-6.4.3-cp311-cp311-macosx_11_0_arm64.whl (37 kB)
# Using cached propcache-0.3.1-cp311-cp311-macosx_11_0_arm64.whl (45 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading yarl-1.19.0-cp311-cp311-macosx_11_0_arm64.whl (94 kB)
# Installing collected packages: sentencepiece, xxhash, urllib3, tqdm, threadpoolctl, tabulate, scipy, safetensors, regex, pyyaml, pyarrow, propcache, portalocker, multidict, lxml, joblib, idna, fsspec, frozenlist, dill, colorama, charset-normalizer, certifi, attrs, aiohappyeyeballs, yarl, scikit-learn, sacrebleu, requests, multiprocess, aiosignal, huggingface-hub, aiohttp, tokenizers, accelerate, transformers, datasets, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# Successfully installed accelerate-1.6.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.16 aiosignal-1.3.2 attrs-25.3.0 certifi-2025.1.31 charset-normalizer-3.4.1 colorama-0.4.6 datasets-3.5.0 dill-0.3.8 evaluate-0.4.3 frozenlist-1.5.0 fsspec-2024.12.0 huggingface-hub-0.30.2 idna-3.10 joblib-1.4.2 lxml-5.3.2 multidict-6.4.3 multiprocess-0.70.16 portalocker-3.1.1 propcache-0.3.1 pyarrow-19.0.1 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 sacrebleu-2.5.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.2 sentencepiece-0.2.0 tabulate-0.9.0 threadpoolctl-3.6.0 tokenizers-0.21.1 tqdm-4.67.1 transformers-4.51.2 urllib3-2.4.0 xxhash-3.5.0 yarl-1.19.0
# Note: you may need to restart the kernel to use updated packages.
